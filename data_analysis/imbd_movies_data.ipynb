# %% [markdown]
# https://www.kaggle.com/PromptCloudHQ/imdb-data

# %% [markdown]
# ### IMDB data from 2006 to 2016

# %% [raw]
# Here's a data set of 1,000 most popular movies on IMDB in the last 10 years. The data points included are:
#
# Title, Genre, Description, Director, Actors, Year, Runtime, Rating, Votes, Revenue, Metascrore

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('IMDB-Movie-Data.csv')
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### 1. Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %% [markdown]
# ### 2. Check Last 10 Rows of The Dataset

# %%
data.tail(10 )
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
print(f"The number of Rows and Columns are {data.shape} Respectively")
# Out:
# The number of Rows and Columns are (1000, 12) Respectively

# %% [markdown]
# ### 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# ### 5. Check Missing Values In The Dataset

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# ### 6. Drop All The  Missing Values

# %%
#missing = np.where(data.isnull().sum())
#data= data.drop(data.index[missing])
data = data.dropna(axis=0)
data
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
print(data.isnull().sum())
print("\n\nALL MISSING VALUES HAVE BEEN WORKED ON\nWE NOW HAVE NO MISSING VALUES IN OUR DATA SET")
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64
#
#
# ALL MISSING VALUES HAVE BEEN WORKED ON
# WE NOW HAVE NO MISSING VALUES IN OUR DATA SET

# %% [markdown]
# ### 7. Check For Duplicate Data

# %%
print(data.duplicated().value_counts())
print("\n\nWe have no duplicte values in our dataset")
# Out:
# False    838
# Name: count, dtype: int64
#
#
# We have no duplicte values in our dataset

# %% [markdown]
# ### 8. Get Overall Statistics About The DataFrame

# %%
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# ### 9. Display Title of The Movie Having Runtime >= 180 Minutes

# %%
print(f"Movies With Runtime Greater or Equal to 180 Minutes are as follows:")
run180 = data[data['Runtime (Minutes)']>=180][['Title', 'Runtime (Minutes)']]
run180
# Out:
# Movies With Runtime Greater or Equal to 180 Minutes are as follows:
#                        Title  Runtime (Minutes)
# 82   The Wolf of Wall Street                180
# 88         The Hateful Eight                187
# 311           La vie d'Adèle                180

# %% [markdown]
# ### 10. In Which Year There Was The Highest Average Voting?

# %%
print("Highest Average Voting Per Year from top to bottom are:")
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Highest Average Voting Per Year from top to bottom are:
# Year
# 2012    290861.483871
# 2006    277232.219512
# 2009    267180.577778
# 2008    266580.145833
# 2007    266530.704545
# 2010    261082.929825
# 2011    259254.736842
# 2013    225531.892857
# 2014    211926.881720
# 2015    129512.651376
# 2016     68437.823232
# Name: Votes, dtype: float64

# %% [markdown]
# ************
# ### Graphical Representation of Average Voting Per Year from Highest to Bottom, Shown Below

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()

# %% [markdown]
# ### 11. In Which Year There Was The Highest Average Revenue?

# %%
print("Highest Average Revenue Per Year from top to bottom are:")
data.groupby('Year')['Revenue (Millions)'].mean().sort_values(ascending=False)
# Out:
# Highest Average Revenue Per Year from top to bottom are:
# Year
# 2009    115.742000
# 2012    110.103065
# 2010    105.081579
# 2008     97.525417
# 2011     93.703333
# 2007     93.074091
# 2013     88.084643
# 2006     87.255610
# 2014     85.433656
# 2015     80.725596
# 2016     55.566111
# Name: Revenue (Millions), dtype: float64

# %% [markdown]
# ***************
# ### Graphical Representation of Average Revenue Per Year from Highest to Bottom, Shown Below

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year")
plt.show()

# %% [markdown]
# We have 2019 coming out as the Highest Revenue Per Year
# *****

# %% [markdown]
# ### 12. Find The Average Rating For Each Director

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %% [markdown]
# ### 13. Display Top 10 Lengthy Movies Title and Runtime

# %%
top10=data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')
top10
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %% [markdown]
# ***************
# ### Graphical Representation of the top 10 lengthy movies, Shown Below

# %%
sns.barplot(x='Runtime (Minutes)',y=top10.index,data=top10)
plt.title('Top 10 Lengtly Movies')
plt.show()

# %% [markdown]
# ### 14. Display Number of Movies Per Year

# %%
dx =data['Year'].value_counts()
dx
# Out:
# Year
# 2016    198
# 2015    109
# 2014     93
# 2013     84
# 2012     62
# 2011     57
# 2010     57
# 2008     48
# 2009     45
# 2007     44
# 2006     41
# Name: count, dtype: int64

# %% [markdown]
# ### Graphical Representation of Number of Movies Per Year

# %%
sns.barplot(x=dx.index, y=dx.values, order=dx.index)
plt.title('Number of Movies Per Year')
plt.show()

# %% [markdown]
# ### 15. Find Most Popular Movie Title (Higest Revenue)

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']][['Title', 'Revenue (Millions)']]. \
set_index("Title")
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63

# %% [markdown]
# ### 16. Display Top 10 Highest Rated Movie Titles And its Directors

# %%
top_10=data.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Title')
top_10
# Out:
#                        Rating                          Director
# Title
# The Dark Knight           9.0                 Christopher Nolan
# Inception                 8.8                 Christopher Nolan
# Interstellar              8.6                 Christopher Nolan
# Kimi no na wa             8.6                    Makoto Shinkai
# The Intouchables          8.6                   Olivier Nakache
# The Prestige              8.5                 Christopher Nolan
# The Departed              8.5                   Martin Scorsese
# The Dark Knight Rises     8.5                 Christopher Nolan
# Whiplash                  8.5                   Damien Chazelle
# The Lives of Others       8.5  Florian Henckel von Donnersmarck

# %% [markdown]
# ### 17. Display Top 10 Highest Revenue Movie Titles

# %%
rev=data.nlargest(10,'Revenue (Millions)')[['Title','Revenue (Millions)']].set_index('Title')
rev
# Out:
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# Jurassic World                                          652.18
# The Avengers                                            623.28
# The Dark Knight                                         533.32
# Rogue One                                               532.17
# Finding Dory                                            486.29
# Avengers: Age of Ultron                                 458.99
# The Dark Knight Rises                                   448.13
# The Hunger Games: Catching Fire                         424.65

# %%
#This prints top 10 Revenue Movies but with the entire dataset and every column

data.sort_values(by='Revenue (Millions)',ascending=False).head(10)
# Out:
#      Rank                                       Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 87     88                                      Avatar
# 85     86                              Jurassic World
# 76     77                                The Avengers
# 54     55                             The Dark Knight
# 12     13                                   Rogue One
# 119   120                                Finding Dory
# 94     95                     Avengers: Age of Ultron
# 124   125                       The Dark Knight Rises
# 578   579             The Hunger Games: Catching Fire
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 87     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 76                Action,Sci-Fi
# 54           Action,Crime,Drama
# 12      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 94      Action,Adventure,Sci-Fi
# 124             Action,Thriller
# 578    Action,Adventure,Mystery
#
# ...

# %% [markdown]
# ### Display Top 10 Highest Revenue Movie Titles

# %%
sns.barplot(x='Revenue (Millions)',y=rev.index,data=rev)
plt.title('Top 10 Highest Revenue Movies Title')
plt.show()

# %% [markdown]
# ### 18.  Find Average Rating of Movies Year Wise

# %%
data.groupby('Year')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2011    6.945614
# 2012    6.933871
# 2009    6.911111
# 2010    6.894737
# 2013    6.832143
# 2014    6.822581
# 2008    6.708333
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %% [markdown]
# ### 19. Does Rating Affect The Revenue?

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)
plt.show()

# %% [markdown]
# ### 20. Classify Movies Based on Ratings [Excellent, Good and Average]

# %%
def rating(rating):   
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

data['Score'] = data['Rating'].apply(rating)
# Out:
# C:\Users\aseid\AppData\Local\Temp\ipykernel_56300\3795867843.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Score'] = data['Rating'].apply(rating)

# %%
data[['Title', 'Rating', 'Score']].sample(10). \
set_index("Title")
# Out:
#                  Rating      Score
# Title
# Warcraft            7.0  Excellent
# Just Go with It     6.4       Good
# Moneyball           7.6  Excellent
# Boyhood             7.9  Excellent
# Thor                7.0  Excellent
# Bonjour Anne        4.9    Average
# The 5th Wave        5.2    Average
# The Gunman          5.8    Average
# Fast & Furious      6.6       Good
# Interstellar        8.6  Excellent

# %% [markdown]
# ### 21. Count Number of Action Movies

# %%
print(f"Number of Action Movies are: {len(data[data['Genre'].str.contains('Action',case=False)])}")
#data[data['Genre'].str.contains('Action',case=False)]
# Out:
# Number of Action Movies are: 277

# %%
data['Genre'].str.contains("Action").value_counts()
# Out:
# Genre
# False    561
# True     277
# Name: count, dtype: int64

# %% [markdown]
# ### 22. Find Unique Values From Genre

# %%
print(f"The Unique Values From Genre are: {data['Genre'].nunique()}")
# Out:
# The Unique Values From Genre are: 189

# %% [markdown]
# ### 23. How Many Films of Each Genre Were Made?

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action,Adventure,Sci-Fi    50
# Comedy,Drama,Romance       30
# Drama                      29
# Drama,Romance              27
# Comedy                     26
#                            ..
# Adventure,Drama,History     1
# Action,Crime,Fantasy        1
# Comedy,Mystery              1
# Adventure,Comedy,Horror     1
# Comedy,Family,Fantasy       1
# Name: count, Length: 189, dtype: int64
