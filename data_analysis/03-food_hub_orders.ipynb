# %%
import pandas as pd

# %%
df = pd.read_csv("foodhub_order.csv")
df
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
import select




df.query("cuisine_type == 'American'")
# Out:
#       order_id  customer_id            restaurant_name cuisine_type  \
# 3      1477334       106968  Blue Ribbon Fried Chicken     American
# 4      1478249        76942           Dirty Bird to Go     American
# 12     1476966       129969  Blue Ribbon Fried Chicken     American
# 14     1478198        62667     Lucky's Famous Burgers     American
# 15     1477414        66222                Shake Shack     American
# ...        ...          ...                        ...          ...
# 1885   1477550        97324                Shake Shack     American
# 1886   1478277        48282          The Meatball Shop     American
# 1887   1476873       237616                Shake Shack     American
# 1891   1476981       138586                Shake Shack     American
# 1894   1477421       397537                  The Smile     American
#
#       cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 3                 29.20         Weekend          3                     25
# ...

# %%
df.query("restaurant_name > rating[10] ")
# Out:
#       order_id  customer_id    restaurant_name   cuisine_type  \
# 5      1477224       147468   Tamarind TriBeCa         Indian
# 6      1477894       157711  The Meatball Shop        Italian
# 13     1477449       104548              Pylos  Mediterranean
# 15     1477414        66222        Shake Shack       American
# 16     1477486       104555      Sushi of Gari       Japanese
# ...        ...          ...                ...            ...
# 1888   1477353       106324  The Meatball Shop        Italian
# 1889   1478190        94152   RedFarm Broadway        Chinese
# 1890   1477316       164776                TAO       Japanese
# 1891   1476981       138586        Shake Shack       American
# 1894   1477421       397537          The Smile       American
#
#       cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 5                 25.22         Weekday          3                     20
# ...

# %%
df['rating'].describe()
# Out:
# count          1898
# unique            4
# top       Not given
# freq            736
# Name: rating, dtype: object

# %%
x = df['cost_of_the_order']
x
# Out:
# 0       30.75
# 1       12.08
# 2       12.23
# 3       29.20
# 4       11.59
#         ...
# 1893    22.31
# 1894    12.18
# 1895    25.22
# 1896    12.18
# 1897    19.45
# Name: cost_of_the_order, Length: 1898, dtype: float64

# %%
new = df[['day_of_the_week','cuisine_type']]
new.head(50)
# Out:
#    day_of_the_week    cuisine_type
# 0          Weekend          Korean
# 1          Weekend        Japanese
# 2          Weekday         Mexican
# 3          Weekend        American
# 4          Weekday        American
# 5          Weekday          Indian
# 6          Weekend         Italian
# 7          Weekday   Mediterranean
# 8          Weekday          Indian
# 9          Weekday          Indian
# 10         Weekday         Chinese
# 11         Weekend         Mexican
# 12         Weekend        American
# 13         Weekend   Mediterranean
# 14         Weekday        American
# 15         Weekend        American
# 16         Weekend        Japanese
# 17         Weekend        Japanese
# 18         Weekend         Chinese
# 19         Weekend        Japanese
# 20         Weekend        American
# 21         Weekend        American
# 22         Weekday        American
# 23         Weekend         Mexican
# 24         Weekday  Middle Eastern
# 25         Weekday  Middle Eastern
# ...

# %%
thai_food = df[df['cuisine_type'] == 'Thai']

# Group the data by day_of_the_week and count the number of orders for each day
day_counts = thai_food['day_of_the_week'].value_counts()

# Find the day with the most Thai food orders
most_ordered_day = day_counts.idxmax()
print(f"The day with the most orders for Thai food is {most_ordered_day}.")
# Out:
# The day with the most orders for Thai food is Weekend.

# %%
df
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
df['delivery_time'].quantile(0)
# Out:
# 15.0

# %%
IQR = df['delivery_time'].quantile(0.75) - df['delivery_time'].quantile(0.25)
IQR
# Out:
# 8.0

# %%
high = df['delivery_time'].quantile(0.75) + 1.5 *IQR
high
# Out:
# 40.0

# %%
low = df['delivery_time'].quantile(0.25) - 1.5 *IQR
low
# Out:
# 8.0

# %%
df['cost_of_the_order'].quantile(0)
# Out:
# 4.47

# %%
MYIQR = df['cost_of_the_order'].quantile(0.75) - df['cost_of_the_order'].quantile(0.25)
MYIQR
# Out:
# 10.2175

# %%
df['cost_of_the_order'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
